# %% [markdown]
# <a href="https://colab.research.google.com/github/pypankj30/Rebounce-Applied-AI-and-Analytics-Codes/blob/main/Python_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("MP1 starting")
# Out:
# MP1 starting

# %% [markdown]
# **Problem 1 - The Introducton Card**

# %%
#creating variables
name = "Pankaj"
city = "Gurgaon"
birth_year = 1997
current_year = 2026
age = current_year - birth_year
print("Hi I'm", name, "from", city, ".", "This year I turn", age, ".")
# Out:
# Hi I'm Pankaj from Gurgaon . This year I turn 29 .

# %% [markdown]
# **Problem 2 . The Currency Exchange**

# %%
inr_amount = 75000
exhange_rate = 1.75
yen = inr_amount * exhange_rate
print(yen)
print(f"Rs {inr_amount} converts to Yen {yen:.2f}")
# Out:
# 131250.0
# Rs 75000 converts to Yen 131250.00

# %% [markdown]
# **Problem 3 . The Grocery Bill**

# %%
#creating variables
bread = 40
milk = 65.50
eggs = 120
total = bread+milk+eggs
average_per_item = total/3
print(f"Total: Rs {total:.2f}")
print(f"Average per item: Rs {average_per_item:.2f}")
# Out:
# Total: Rs 225.50
# Average per item: Rs 75.17
